# %%
import joblib

from sklearn.metrics import log_loss
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelEncoder

import numpy as np 
import pandas as pd 
import seaborn as sns
import folium
from folium.plugins import HeatMap, TimestampedGeoJson
import matplotlib.pyplot as plt
from random import sample
from folium import TileLayer

# %%
data=pd.read_csv('cleaned_data.csv')

# %%
data
# Out:
#          CMPLNT_NUM  year  month  day    weekday  hour  ADDR_PCT_CD OFNS_DESC  \
# 0         642234217  2013     10   28     Monday    13        120.0  PROPERTY
# 1         242465164  2012      5    9  Wednesday    20         24.0  PERSONAL
# 2         927207428  2014      1    3     Friday    13        108.0  PROPERTY
# 3         572616350  2014      8   18     Monday    14        102.0  PROPERTY
# 4         593660503  2012      2   20     Monday     1         32.0  PERSONAL
# ...             ...   ...    ...  ...        ...   ...          ...       ...
# 5259582   120248300  2018      9   11    Tuesday    22        110.0  PROPERTY
# 5259583   180596560  2018      1   15     Monday    14         47.0  PROPERTY
# 5259584   142216265  2018      8    7    Tuesday    14         78.0  PERSONAL
# 5259585   225471008  2018     12    2     Sunday     4        109.0  PERSONAL
# 5259586   146134182  2018      8    3     Friday    22         41.0  PROPERTY
#
#          COMPLETED  CRIME_CLASS        BORO_NM           PREM_TYP_DESC  \
# 0        COMPLETED  MISDEMEANOR  STATEN ISLAND  RESIDENCE - APT. HOUSE
# 1        COMPLETED  MISDEMEANOR      MANHATTAN                  STREET
# 2        ATTEMPTED       FELONY         QUEENS  RESIDENCE - APT. HOUSE
# 3        COMPLETED  MISDEMEANOR         QUEENS                  STREET
# 4        COMPLETED  MISDEMEANOR      MANHATTAN  RESIDENCE - APT. HOUSE
# ...            ...          ...            ...                     ...
# 5259582  COMPLETED       FELONY         QUEENS                  STREET
# 5259583  COMPLETED  MISDEMEANOR          BRONX  RESIDENCE - APT. HOUSE
# 5259584  COMPLETED  MISDEMEANOR       BROOKLYN         PARK/PLAYGROUND
# 5259585  COMPLETED  MISDEMEANOR         QUEENS  RESIDENCE - APT. HOUSE
# 5259586  COMPLETED       FELONY          BRONX                  STREET
#
#         SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX   Latitude  Longitude  \
# 0              UNKNOWN         UNKNOWN        U  40.627061 -74.077149
# 1              UNKNOWN         UNKNOWN        U  40.800966 -73.969047
# 2              UNKNOWN         UNKNOWN        M  40.745242 -73.894253
# 3              UNKNOWN         UNKNOWN        U  40.683660 -73.851542
# 4                25-44           BLACK        M  40.811522 -73.940601
# ...                ...             ...      ...        ...        ...
# 5259582          18-24  WHITE HISPANIC        M  40.741889 -73.859886
# 5259583          45-64  BLACK HISPANIC        M  40.878054 -73.863244
# 5259584            <18           BLACK        M  40.672202 -73.983786
# 5259585          25-44  WHITE HISPANIC        M  40.785050 -73.856852
# 5259586        UNKNOWN         UNKNOWN        U  40.814612 -73.903637
#
#         VIC_AGE_GROUP                  VIC_RACE VIC_SEX
# 0               45-64                     WHITE       M
# 1             UNKNOWN                   UNKNOWN       E
# 2               45-64  ASIAN / PACIFIC ISLANDER       M
# 3               18-24                     WHITE       F
# 4               25-44                     BLACK       F
# ...               ...                       ...     ...
# 5259582       UNKNOWN                   UNKNOWN       E
# 5259583         45-64                     BLACK       F
# 5259584         18-24                     BLACK       M
# 5259585         25-44  ASIAN / PACIFIC ISLANDER       F
# 5259586         25-44            BLACK HISPANIC       F
#
# [5259587 rows x 20 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259587 entries, 0 to 5259586
# Data columns (total 20 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CMPLNT_NUM      int64
#  1   year            int64
#  2   month           int64
#  3   day             int64
#  4   weekday         object
#  5   hour            int64
#  6   ADDR_PCT_CD     float64
#  7   OFNS_DESC       object
#  8   COMPLETED       object
#  9   CRIME_CLASS     object
#  10  BORO_NM         object
#  11  PREM_TYP_DESC   object
#  12  SUSP_AGE_GROUP  object
#  13  SUSP_RACE       object
#  14  SUSP_SEX        object
#  15  Latitude        float64
#  16  Longitude       float64
#  17  VIC_AGE_GROUP   object
#  18  VIC_RACE        object
#  19  VIC_SEX         object
# dtypes: float64(3), int64(5), object(12)
# memory usage: 802.5+ MB

# %% [markdown]
# # I. Adding location code column

# %%
from openlocationcode import openlocationcode as olc

data = data.dropna(subset=['Latitude', 'Longitude'])

data['LOCATION_CODE'] = data.apply(
    lambda row: olc.encode(row['Latitude'], row['Longitude'], codeLength=8),
    axis=1
)

print(data[['Latitude', 'Longitude', 'LOCATION_CODE']].head())
# Out:
#     Latitude  Longitude LOCATION_CODE
# 0  40.627061 -74.077149     87G7JWGF+
# 1  40.800966 -73.969047     87G8R22J+
# 2  40.745242 -73.894253     87G8P4W4+
# 3  40.683660 -73.851542     87G8M4MX+
# 4  40.811522 -73.940601     87G8R365+

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5259587 entries, 0 to 5259586
# Data columns (total 21 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CMPLNT_NUM      int64
#  1   year            int64
#  2   month           int64
#  3   day             int64
#  4   weekday         object
#  5   hour            int64
#  6   ADDR_PCT_CD     float64
#  7   OFNS_DESC       object
#  8   COMPLETED       object
#  9   CRIME_CLASS     object
#  10  BORO_NM         object
#  11  PREM_TYP_DESC   object
#  12  SUSP_AGE_GROUP  object
#  13  SUSP_RACE       object
#  14  SUSP_SEX        object
#  15  Latitude        float64
#  16  Longitude       float64
#  17  VIC_AGE_GROUP   object
#  18  VIC_RACE        object
#  19  VIC_SEX         object
#  20  LOCATION_CODE   object
# dtypes: float64(3), int64(5), object(13)
# memory usage: 842.7+ MB

# %% [markdown]
# # II. Precizing target feature

# %%
filtered_df = data[~data['OFNS_DESC'].isin(['ADMINISTRATIVE', 'OTHER'])]
data=filtered_df
data.OFNS_DESC.unique()
# Out:
# array(['PROPERTY', 'PERSONAL', 'SEXUAL', 'DRUGS/ALCOHOL'], dtype=object)

# %%
data = data.rename(columns={'OFNS_DESC': 'TARGET'})

data.head()
# Out:
#    CMPLNT_NUM  year  month  day    weekday  hour  ADDR_PCT_CD    TARGET  \
# 0   642234217  2013     10   28     Monday    13        120.0  PROPERTY
# 1   242465164  2012      5    9  Wednesday    20         24.0  PERSONAL
# 2   927207428  2014      1    3     Friday    13        108.0  PROPERTY
# 3   572616350  2014      8   18     Monday    14        102.0  PROPERTY
# 4   593660503  2012      2   20     Monday     1         32.0  PERSONAL
#
#    COMPLETED  CRIME_CLASS  ...           PREM_TYP_DESC SUSP_AGE_GROUP  \
# 0  COMPLETED  MISDEMEANOR  ...  RESIDENCE - APT. HOUSE        UNKNOWN
# 1  COMPLETED  MISDEMEANOR  ...                  STREET        UNKNOWN
# 2  ATTEMPTED       FELONY  ...  RESIDENCE - APT. HOUSE        UNKNOWN
# 3  COMPLETED  MISDEMEANOR  ...                  STREET        UNKNOWN
# 4  COMPLETED  MISDEMEANOR  ...  RESIDENCE - APT. HOUSE          25-44
#
#   SUSP_RACE SUSP_SEX   Latitude  Longitude  VIC_AGE_GROUP  \
# 0   UNKNOWN        U  40.627061 -74.077149          45-64
# 1   UNKNOWN        U  40.800966 -73.969047        UNKNOWN
# 2   UNKNOWN        M  40.745242 -73.894253          45-64
# 3   UNKNOWN        U  40.683660 -73.851542          18-24
# 4     BLACK        M  40.811522 -73.940601          25-44
#
#                    VIC_RACE VIC_SEX LOCATION_CODE
# 0                     WHITE       M     87G7JWGF+
# 1                   UNKNOWN       E     87G8R22J+
# 2  ASIAN / PACIFIC ISLANDER       M     87G8P4W4+
# 3                     WHITE       F     87G8M4MX+
# 4                     BLACK       F     87G8R365+
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4612689 entries, 0 to 5259586
# Data columns (total 21 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CMPLNT_NUM      int64
#  1   year            int64
#  2   month           int64
#  3   day             int64
#  4   weekday         object
#  5   hour            int64
#  6   ADDR_PCT_CD     float64
#  7   TARGET          object
#  8   COMPLETED       object
#  9   CRIME_CLASS     object
#  10  BORO_NM         object
#  11  PREM_TYP_DESC   object
#  12  SUSP_AGE_GROUP  object
#  13  SUSP_RACE       object
#  14  SUSP_SEX        object
#  15  Latitude        float64
#  16  Longitude       float64
#  17  VIC_AGE_GROUP   object
#  18  VIC_RACE        object
#  19  VIC_SEX         object
#  20  LOCATION_CODE   object
# dtypes: float64(3), int64(5), object(13)
# memory usage: 774.2+ MB

# %%
# Select the required columns
columns_to_extract = [
    'TARGET', 'year', 'month', 'hour', 'weekday', 'ADDR_PCT_CD', 
    'CRIME_CLASS', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'LOCATION_CODE'
]

# Extract the data
extracted_data = data[columns_to_extract]

# Save the extracted data to a new CSV file
extracted_data.to_csv('original_data.csv', index=False)

print("Data saved successfully to 'original_data.csv'")
# Out:
# Data saved successfully to 'original_data.csv'

# %% [markdown]
# # III. Encoding categorical data

# %%
num_columns = data.select_dtypes(include=['int64', 'float64']).columns

# %%
num_data = data[num_columns].copy()

# %%
# Mapping non-numerical features
target_map = {val: idx for idx, val in enumerate(data['TARGET'].unique())}
crime_class_map = {val: idx for idx, val in enumerate(data['CRIME_CLASS'].unique())}
boro_map = {val: idx for idx, val in enumerate(data['BORO_NM'].unique())}
prem_typ_desc_map = {val: idx for idx, val in enumerate(data['PREM_TYP_DESC'].unique())}
susp_age_group_map = {val: idx for idx, val in enumerate(data['SUSP_AGE_GROUP'].unique())}
susp_race_map = {val: idx for idx, val in enumerate(data['SUSP_RACE'].unique())}
susp_sex_map = {val: idx for idx, val in enumerate(data['SUSP_SEX'].unique())}
vic_age_group_map = {val: idx for idx, val in enumerate(data['VIC_AGE_GROUP'].unique())}
vic_race_map = {val: idx for idx, val in enumerate(data['VIC_RACE'].unique())}
vic_sex_map = {val: idx for idx, val in enumerate(data['VIC_SEX'].unique())}

weekday_map = {
    'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3,
    'Friday': 4, 'Saturday': 5, 'Sunday': 6
}

completed_map = {val: idx for idx, val in enumerate(data['COMPLETED'].unique())}

location_code_map = {val: idx for idx, val in enumerate(data['LOCATION_CODE'].unique())}

# %%
# 2. Map non-numerical features to numerical labels using the mappings
num_data['TARGET'] = data['TARGET'].map(target_map)
num_data['CRIME_CLASS'] = data['CRIME_CLASS'].map(crime_class_map)
num_data['BORO_NM'] = data['BORO_NM'].map(boro_map)
num_data['PREM_TYP_DESC'] = data['PREM_TYP_DESC'].map(prem_typ_desc_map)
num_data['SUSP_AGE_GROUP'] = data['SUSP_AGE_GROUP'].map(susp_age_group_map)
num_data['SUSP_RACE'] = data['SUSP_RACE'].map(susp_race_map)
num_data['SUSP_SEX'] = data['SUSP_SEX'].map(susp_sex_map)
num_data['VIC_AGE_GROUP'] = data['VIC_AGE_GROUP'].map(vic_age_group_map)
num_data['VIC_RACE'] = data['VIC_RACE'].map(vic_race_map)
num_data['VIC_SEX'] = data['VIC_SEX'].map(vic_sex_map)

num_data['weekday'] = data['weekday'].map(weekday_map)

num_data['COMPLETED'] = data['COMPLETED'].map(completed_map)

num_data['LOCATION_CODE'] = data['LOCATION_CODE'].map(location_code_map)


num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4612689 entries, 0 to 5259586
# Data columns (total 21 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CMPLNT_NUM      int64
#  1   year            int64
#  2   month           int64
#  3   day             int64
#  4   hour            int64
#  5   ADDR_PCT_CD     float64
#  6   Latitude        float64
#  7   Longitude       float64
#  8   TARGET          int64
#  9   CRIME_CLASS     int64
#  10  BORO_NM         int64
#  11  PREM_TYP_DESC   int64
#  12  SUSP_AGE_GROUP  int64
#  13  SUSP_RACE       int64
#  14  SUSP_SEX        int64
#  15  VIC_AGE_GROUP   int64
#  16  VIC_RACE        int64
#  17  VIC_SEX         int64
#  18  weekday         int64
#  19  COMPLETED       int64
#  20  LOCATION_CODE   int64
# dtypes: float64(3), int64(18)
# memory usage: 774.2 MB

# %%
num_data.head()
# Out:
#    CMPLNT_NUM  year  month  day  hour  ADDR_PCT_CD   Latitude  Longitude  \
# 0   642234217  2013     10   28    13        120.0  40.627061 -74.077149
# 1   242465164  2012      5    9    20         24.0  40.800966 -73.969047
# 2   927207428  2014      1    3    13        108.0  40.745242 -73.894253
# 3   572616350  2014      8   18    14        102.0  40.683660 -73.851542
# 4   593660503  2012      2   20     1         32.0  40.811522 -73.940601
#
#    TARGET  CRIME_CLASS  ...  PREM_TYP_DESC  SUSP_AGE_GROUP  SUSP_RACE  \
# 0       0            0  ...              0               0          0
# 1       1            0  ...              1               0          0
# 2       0            1  ...              0               0          0
# 3       0            0  ...              1               0          0
# 4       1            0  ...              0               1          1
#
#    SUSP_SEX  VIC_AGE_GROUP  VIC_RACE  VIC_SEX  weekday  COMPLETED  \
# 0         0              0         0        0        0          0
# 1         0              1         1        1        2          0
# 2         1              0         2        0        4          1
# 3         0              2         0        2        0          0
# 4         1              3         3        2        0          0
#
#    LOCATION_CODE
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
#
# [5 rows x 21 columns]

# %%
# 4. Encoding the missing categorical columns ('COMPLETED', 'LOCATION_CODE', 'weekday')
num_data['COMPLETED'] = data['COMPLETED'].map(lambda x: 1 if x == 'COMPLETED' else 0)  # Example binary encoding
num_data['LOCATION_CODE'] = data['LOCATION_CODE'].astype("category").cat.codes  # Encoding LOCATION_CODE
num_data['weekday'] = data['weekday'].map({
    'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6
})  # Encoding days of the week to numbers

# Verifying the changes
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4612689 entries, 0 to 5259586
# Data columns (total 21 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   CMPLNT_NUM      int64
#  1   year            int64
#  2   month           int64
#  3   day             int64
#  4   hour            int64
#  5   ADDR_PCT_CD     float64
#  6   Latitude        float64
#  7   Longitude       float64
#  8   TARGET          int64
#  9   CRIME_CLASS     int64
#  10  BORO_NM         int64
#  11  PREM_TYP_DESC   int64
#  12  SUSP_AGE_GROUP  int64
#  13  SUSP_RACE       int64
#  14  SUSP_SEX        int64
#  15  VIC_AGE_GROUP   int64
#  16  VIC_RACE        int64
#  17  VIC_SEX         int64
#  18  weekday         int64
#  19  COMPLETED       int64
#  20  LOCATION_CODE   int16
# dtypes: float64(3), int16(1), int64(17)
# memory usage: 747.8 MB

# %%
# Display all mappings

# Mapping non-numerical features
print("TARGET mapping:\n", target_map, "\n")
print("CRIME_CLASS mapping:\n", crime_class_map, "\n")
print("BORO_NM mapping:\n", boro_map, "\n")
print("PREM_TYP_DESC mapping:\n", prem_typ_desc_map, "\n")
print("SUSP_AGE_GROUP mapping:\n", susp_age_group_map, "\n")
print("SUSP_RACE mapping:\n", susp_race_map, "\n")
print("SUSP_SEX mapping:\n", susp_sex_map, "\n")
print("VIC_AGE_GROUP mapping:\n", vic_age_group_map, "\n")
print("VIC_RACE mapping:\n", vic_race_map, "\n")
print("VIC_SEX mapping:\n", vic_sex_map, "\n")
print("weekday mapping:\n", weekday_map, "\n")
print("COMPLETED mapping:\n", completed_map, "\n")
print("LOCATION_CODE mapping:\n", location_code_map, "\n")
# Out:
# TARGET mapping:
#  {'PROPERTY': 0, 'PERSONAL': 1, 'SEXUAL': 2, 'DRUGS/ALCOHOL': 3}
#
# CRIME_CLASS mapping:
#  {'MISDEMEANOR': 0, 'FELONY': 1, 'VIOLATION': 2}
#
# BORO_NM mapping:
#  {'STATEN ISLAND': 0, 'MANHATTAN': 1, 'QUEENS': 2, 'BROOKLYN': 3, 'BRONX': 4, 'UNKNOWN': 5}
#
# PREM_TYP_DESC mapping:
#  {'RESIDENCE - APT. HOUSE': 0, 'STREET': 1, 'OPEN AREAS (OPEN LOTS)': 2, 'RESIDENCE-HOUSE': 3, 'CHAIN STORE': 4, 'RESIDENCE - PUBLIC HOUSING': 5, 'HOSPITAL': 6, 'RESTAURANT/DINER': 7, 'DEPARTMENT STORE': 8, 'OTHER': 9, 'COMMERCIAL BUILDING': 10, 'PUBLIC BUILDING': 11, 'CANDY STORE': 12, 'TRANSIT - NYC SUBWAY': 13, 'GROCERY/BODEGA': 14, 'BOOK/CARD': 15, 'TAXI (YELLOW LICENSED)': 16, 'AIRPORT TERMINAL': 17, 'BAR/NIGHT CLUB': 18, 'TRANSIT FACILITY (OTHER)': 19, 'BEAUTY & NAIL SALON': 20, 'FOOD SUPERMARKET': 21, 'TELECOMM. STORE': 22, 'PARKING LOT/GARAGE (PRIVATE)': 23, 'STORE UNCLASSIFIED': 24, 'PARKING LOT/GARAGE (PUBLIC)': 25, 'FAST FOOD': 26, 'GYM/FITNESS FACILITY': 27, 'CLOTHING/BOUTIQUE': 28, 'PARK/PLAYGROUND': 29, 'DRUG STORE': 30, 'BUS TERMINAL': 31, 'GAS STATION': 32, 'DRY CLEANER/LAUNDRY': 33, 'ABANDONED BUILDING': 34, 'PUBLIC SCHOOL': 35, 'VARIETY STORE': 36, 'HOTEL/MOTEL': 37, 'CHURCH': 38, 'BANK': 39, 'LIQUOR STORE': 40, 'CHECK CASHING BUSINESS': 41, 'STORAGE FACILITY': 42, 'CONSTRUCTION SITE': 43, 'TAXI (LIVERY LICENSED)': 44, 'DOCTOR/DENTIST OFFICE': 45, 'SMALL MERCHANT': 46, 'SOCIAL CLUB/POLICY': 47, 'PHOTO/COPY': 48, 'BUS STOP': 49, 'HIGHWAY/PARKWAY': 50, 'MARINA/PIER': 51, 'VIDEO STORE': 52, 'BUS (NYC TRANSIT)': 53, 'BUS (OTHER)': 54, 'PRIVATE/PAROCHIAL SCHOOL': 55, 'BRIDGE': 56, 'FERRY/FERRY TERMINAL': 57, 'ATM': 58, 'FACTORY/WAREHOUSE': 59, 'TAXI/LIVERY (UNLICENSED)': 60, 'JEWELRY': 61, 'SHOE': 62, 'TUNNEL': 63, 'SYNAGOGUE': 64, 'OTHER HOUSE OF WORSHIP': 65, 'MOSQUE': 66, 'TRAMWAY': 67, 'CEMETERY': 68, 'LOAN COMPANY': 69, 'HOMELESS SHELTER': 70, 'MAILBOX OUTSIDE': 71, 'MAILBOX INSIDE': 72, 'DAYCARE FACILITY': 73}
#
# SUSP_AGE_GROUP mapping:
#  {'UNKNOWN': 0, '25-44': 1, '45-64': 2, '<18': 3, '18-24': 4, '65+': 5}
#
# SUSP_RACE mapping:
#  {'UNKNOWN': 0, 'BLACK': 1, 'BLACK HISPANIC': 2, 'WHITE': 3, 'WHITE HISPANIC': 4, 'ASIAN / PACIFIC ISLANDER': 5, 'AMERICAN INDIAN/ALASKAN NATIVE': 6, 'OTHER': 7}
#
# SUSP_SEX mapping:
#  {'U': 0, 'M': 1, 'F': 2}
#
# VIC_AGE_GROUP mapping:
#  {'45-64': 0, 'UNKNOWN': 1, '18-24': 2, '25-44': 3, '65+': 4, '<18': 5}
#
# VIC_RACE mapping:
#  {'WHITE': 0, 'UNKNOWN': 1, 'ASIAN / PACIFIC ISLANDER': 2, 'BLACK': 3, 'BLACK HISPANIC': 4, 'WHITE HISPANIC': 5, 'AMERICAN INDIAN/ALASKAN NATIVE': 6, 'OTHER': 7}
#
# VIC_SEX mapping:
#  {'M': 0, 'E': 1, 'F': 2, 'D': 3, 'U': 4}
#
# weekday mapping:
#  {'Monday': 0, 'Tuesday': 1, 'Wednesday': 2, 'Thursday': 3, 'Friday': 4, 'Saturday': 5, 'Sunday': 6}
#
# COMPLETED mapping:
#  {'COMPLETED': 0, 'ATTEMPTED': 1}
#
# LOCATION_CODE mapping:
#  {'87G7JWGF+': 0, '87G8R22J+': 1, '87G8P4W4+': 2, '87G8M4MX+': 3, '87G8R365+': 4, '87G8P2R8+': 5, '87G8J3H2+': 6, '87G8M3HJ+': 7, '87G8V5H3+': 8, '87G8J3J3+': 9, '87G8Q2XX+': 10, '87G8M38W+': 11, '87G8R4VP+': 12, '87G8V35V+': 13, '87G8M343+': 14, '87G8M35P+': 15, '87G7JRFM+': 16, '87G8P2P5+': 17, '87G8P2P2+': 18, '87G8V458+': 19, '87G8Q548+': 20, '87G8H2JP+': 21, '87G8M433+': 22, '87G8Q2JC+': 23, '87G8Q246+': 24, '87G8V3PV+': 25, '87G8Q273+': 26, '87G8V554+': 27, '87G8M3VR+': 28, '87G8M23W+': 29, '87G8M3C2+': 30, '87G8P579+': 31, '87G8P6JH+': 32, '87G8Q267+': 33, '87G8Q25P+': 34, '87G8P296+': 35, '87G8P5CV+': 36, '87G8J2Q2+': 37, '87G7JXRR+': 38, '87G8V46P+': 39, '87G8V49C+': 40, '87G8M36V+': 41, '87G8Q388+': 42, '87G8V544+': 43, '87G8R3FW+': 44, '87G8Q3P5+': 45, '87G8P2P8+': 46, '87G8P2RC+': 47, '87G8M3JW+': 48, '87G8J36Q+': 49, '87G8V522+': 50, '87G8P2V4+': 51, '87G8P377+': 52, '87G8R37X+': 53, '87G8H7X2+': 54, '87G8M3HH+': 55, '87G8V4GM+': 56, '87G8V36X+': 57, '87G8H6V3+': 58, '87G8M3FM+': 59, '87G7HR68+': 60, '87G8P73C+': 61, '87G8M346+': 62, '87G8P35C+': 63, '87G8P2Q3+': 64, '87G8Q37P+': 65, '87G8R23P+': 66, '87G8Q35J+': 67, '87G8M6HF+': 68, '87G8P3WF+': 69, '87G8P2W6+': 70, '87G8V439+': 71, '87G8R3G3+': 72, '87G8Q2QX+': 73, '87G8P295+': 74, '87G8P4XG+': 75, '87G8R39H+': 76, '87G8M3HX+': 77, '87G8P4XP+': 78, '87G8M35J+': 79, '87G8M4HW+': 80, '87G8M493+': 81, '87G8M2V7+': 82, '87G8Q225+': 83, '87G8P4MH+': 84, '87G8R3F7+': 85, '87G8M3CC+': 86, '87G8P66J+': 87, '87G8M3GF+': 88, '87G8H3W6+': 89, '87G8V4VR+': 90, '87G8M22Q+': 91, '87G8J2W2+': 92, '87G7HV9R+': 93, '87G8M34F+': 94, '87G8R4QW+': 95, '87G8R3QG+': 96, '87G8V455+': 97, '87G8P3P7+': 98, '87G8R5FG+': 99, '87G8Q3W7+': 100, '87G8M2MC+': 101, '87G7HXFX+': 102, '87G8V4M5+': 103, '87G7PXXX+': 104, '87G8Q35X+': 105, '87G8M5FR+': 106, '87G8R4CM+': 107, '87G8P4MV+': 108, '87G8R3CR+': 109, '87G8M2W8+': 110, '87G8P2C8+': 111, '87G8P425+': 112, '87G8V449+': 113, '87G8J3PG+': 114, '87G8M425+': 115, '87G8M399+': 116, '87G8P4VQ+': 117, '87G8M2HJ+': 118, '87G8R372+': 119, '87G8J24P+': 120, '87G7JRGV+': 121, '87G8R4MC+': 122, '87G8P2H7+': 123, '87G8P4G4+': 124, '87G8P4RV+': 125, '87G8H5H8+': 126, '87G7PX8V+': 127, '87G8M328+': 128, '87G8Q333+': 129, '87G8M33C+': 130, '87G8M3F9+': 131, '87G8M6XR+': 132, '87G8Q46F+': 133, '87G8H2JM+': 134, '87G8M36J+': 135, '87G8Q2JW+': 136, '87G8Q27C+': 137, '87G8Q534+': 138, '87G8M3CP+': 139, '87G8H2PX+': 140, '87G8R326+': 141, '87G7PXWW+': 142, '87G8Q35C+': 143, '87G8P626+': 144, '87G8Q25M+': 145, '87G8M5J6+': 146, '87G8Q58H+': 147, '87G8P56P+': 148, '87G8M3H5+': 149, '87G8M295+': 150, '87G8P68M+': 151, '87G8R4X2+': 152, '87G8V42J+': 153, '87G8H6V7+': 154, '87G8M4HQ+': 155, '87G8Q495+': 156, '87G8R3X6+': 157, '87G8M22P+': 158, '87G8R36H+': 159, '87G8M3R5+': 160, '87G8R4V7+': 161, '87G7PXQX+': 162, '87G8M294+': 163, '87G8R3M5+': 164, '87G8Q226+': 165, '87G8R3MJ+': 166, '87G8Q277+': 167, '87G8M37R+': 168, '87G8M3HG+': 169, '87G8M25X+': 170, '87G7JW6H+': 171, '87G8R38J+': 172, '87G8Q727+': 173, '87G8P29X+': 174, '87G8M457+': 175, '87G8M779+': 176, '87G8R3CM+': 177, '87G8R26X+': 178, '87G8Q268+': 179, '87G8V3PW+': 180, '87G8R4RW+': 181, '87G8R344+': 182, '87G8R3WJ+': 183, '87G8Q3M4+': 184, '87G8Q245+': 185, '87G8M3CV+': 186, '87G8P37C+': 187, '87G8M6MV+': 188, '87G8P644+': 189, '87G8J257+': 190, '87G8Q2H8+': 191, '87G8P54X+': 192, '87G8M5MH+': 193, '87G8R3XV+': 194, '87G8Q37J+': 195, '87G8M3V5+': 196, '87G8R4HM+': 197, '87G8Q4R8+': 198, '87G8R23M+': 199, '87G7GRRP+': 200, '87G8M3QP+': 201, '87G8J3M8+': 202, '87G8P4X2+': 203, '87G8H2GM+': 204, '87G8Q46H+': 205, '87G8M2WV+': 206, '87G8M26Q+': 207, '87G8P2RR+': 208, '87G8J3XV+': 209, '87G8R3W6+': 210, '87G8M42J+': 211, '87G7PX5V+': 212, '87G8V5W4+': 213, '87G8J4R4+': 214, '87G8M3H9+': 215, '87G8M38Q+': 216, '87G8R24R+': 217, '87G8P57V+': 218, '87G8M369+': 219, '87G8H7W5+': 220, '87G8R47M+': 221, '87G8R4C5+': 222, '87G7PXCX+': 223, '87G8J3X9+': 224, '87G8R4HP+': 225, '87G8M3PC+': 226, '87G7PXCR+': 227, '87G ...

# %% [markdown]
# # IV. Correlation matrix

# %%
correlation_matrix = num_data.corr()
print(correlation_matrix)
# Out:
#                 CMPLNT_NUM      year     month       day      hour  \
# CMPLNT_NUM        1.000000 -0.000384  0.000213  0.000062 -0.000425
# year             -0.000384  1.000000 -0.002996  0.006347 -0.009601
# month             0.000213 -0.002996  1.000000  0.010210  0.002097
# day               0.000062  0.006347  0.010210  1.000000  0.017960
# hour             -0.000425 -0.009601  0.002097  0.017960  1.000000
# ADDR_PCT_CD       0.000178 -0.018685 -0.000930 -0.003227 -0.002476
# Latitude         -0.000128  0.018989 -0.002062  0.002377  0.000611
# Longitude        -0.000227  0.002534 -0.001885  0.001103  0.006160
# TARGET           -0.001000  0.011389 -0.021741 -0.012265 -0.001412
# CRIME_CLASS      -0.000464  0.031871  0.009813 -0.001056 -0.005871
# BORO_NM          -0.000254  0.006860 -0.002376  0.001677  0.016512
# PREM_TYP_DESC     0.000804  0.022570 -0.002813 -0.002221 -0.004594
# SUSP_AGE_GROUP   -0.000662  0.256835  0.007914  0.001912  0.010222
# SUSP_RACE        -0.000348  0.205897  0.008077  0.000940 -0.006394
# SUSP_SEX         -0.000416  0.235219  0.011480  0.003652  0.004668
# VIC_AGE_GROUP     0.000541  0.001692  0.006332 -0.001267 -0.008109
# VIC_RACE          0.000053  0.045863  0.004928  0.003508 -0.017221
# VIC_SEX           0.000127  0.015939 -0.003886  0.000338  0.026519
# weekday          -0.000656  0.001379  0.001246  0.000362 -0.058098
# COMPLETED         0.000732 -0.001111 -0.001356 -0.001521  0.008712
# LOCATION_CODE    -0.000229  0.017979 -0.002315  0.002371  0.006734
#
#                 ADDR_PCT_CD  Latitude  Longitude    TARGET  CRIME_CLASS  ...  \
# CMPLNT_NUM         0.000178 -0.000128  -0.000227 -0.001000    -0.000464  ...
# year              -0.018685  0.018989   0.002534  0.011389     0.031871  ...
# month             -0.000930 -0.002062  -0.001885 -0.021741     0.009813  ...
# day               -0.003227  0.002377   0.001103 -0.012265    -0.001056  ...
# hour              -0.002476  0.000611   0.006160 -0.001412    -0.005871  ...
# ADDR_PCT_CD        1.000000 -0.448538   0.242969  0.003598     0.040433  ...
# Latitude          -0.448538  1.000000   0.296829  0.031045    -0.029094  ...
# Longitude          0.242969  0.296829   1.000000  0.007387     0.019074  ...
# TARGET             0.003598  0.031045   0.007387  1.000000     0.282134  ...
# CRIME_CLASS        0.040433 -0.029094   0.019074  0.282134     1.000000  ...
# BORO_NM            0.044089  0.234494   0.405739  0.067667    -0.006726  ...
# PREM_TYP_DESC     -0.069392 -0.003859  -0.062402 -0.107321    -0.036262  ...
# SUSP_AGE_GROUP     0.008838  0.010801   0.016029  0.200109     0.121930  ...
# SUSP_RACE          0.033348  0.015330   0.003601  0.234980     0.213088  ...
# SUSP_SEX           0.010494  0.002257   0.013142  0.271316     0.294747  ...
# VIC_AGE_GROUP      0.034007 -0.009008   0.022789 -0.011331     0.106084  ...
# VIC_RACE           0.036276  0.145380   0.172440  0.024827     0.115565  ...
# VIC_SEX           -0.062122  0.005428  -0.039787 -0.090297    -0.033771  ...
# weekday           -0.001223 -0.001742  -0.002986  0.026753    -0.018590  ...
# COMPLETED          0.002062 -0.002838  -0.004396  0.050893    -0.031940  ...
# LOCATION_CODE     -0.336306  0.920158   0.459189  0.031458    -0.023550  ...
#
#                 PREM_TYP_DESC  SUSP_AGE_GROUP  SUSP_RACE  SUSP_SEX  \
# CMPLNT_NUM           0.000804       -0.000662  -0.000348 -0.000416
# year                 0.022570        0.256835   0.205897  0.235219
# month               -0.002813        0.007914   0.008077  0.011480
# day                 -0.002221        0.001912   0.000940  0.003652
# hour                -0.004594        0.010222  -0.006394  0.004668
# ADDR_PCT_CD         -0.069392        0.008838   0.033348  0.010494
# Latitude            -0.003859        0.010801   0.015330  0.002257
# Longitude           -0.062402        0.016029   0.003601  0.013142
# TARGET              -0.107321        0.200109   0.234980  0.271316
# CRIME_CLASS         -0.036262        0.121930   0.213088  0.294747
# BORO_NM             -0.099784        0.028169  -0.007603  0.022118
# PREM_TYP_DESC        1.000000       -0.030543  -0.018266 -0.010177
# SUSP_AGE_GROUP      -0.030543        1.000000   0.455674  0.515180
# SUSP_RACE           -0.018266        0.455674   1.000000  0.650301
# SUSP_SEX            -0.010177        0.515180   0.650301  1.000000
# VIC_AGE_GROUP       -0.051156        0.029427   0.064357  0.100559
# VIC_RACE            -0.097259        0.082064   0.119862  0.151410
# VIC_SEX              0.164497        0.061321   0.034172  0.065409
# weekday             -0.022349        0.001341   0.013928  0.000632
# COMPLETED           -0.013780        0.001678  -0.003191 -0.004586
# LOCATION_CODE       -0.015392        0.014609   0.019283  0.005526
#
#                 VIC_AGE_GROUP  VIC_RACE   VIC_SEX   weekday  COMPLETED  \
# CMPLNT_NUM           0.000541  0.000053  0.000127 -0.000656   0.000732
# year                 0.001692  0.045863  0.015939  0.001379  -0.001111
# month                0.006332  0.004928 -0.003886  0.001246  -0.001356
# day                 -0.001267  0.003508  0.000338  0.000362  -0.001521
# hour                -0.008109 -0.017221  0.026519 -0.058098   0.008712
# ADDR_PCT_CD          0.034007  0.036276 -0.062122 -0.001223   0.002062
# Latitude            -0.009008  0.145380  0.005428 -0.001742  -0.002838
# Longitude            0.022789  0.172440 -0.039787 -0.002986  -0.004396
# TARGET              -0.011331  0.024827 -0.090297  0.026753   0.050893
# CRIME_CLASS          0.106084  0.115565 -0.033771 -0.018590  -0.031940
# BORO_NM              0.028612  0.174216 -0.052705 -0.008413   0.002239
# PREM_TYP_DESC       -0.051156 -0.097259  0.164497 -0.022349  -0.013780
# SUSP_AGE_GROUP       0.029427  0.082064  0.061321  0.001341   0.001678
# SUSP_RACE            0.064357  0.119862  0.034172  0.013928  -0.003191
# SUSP_SEX             0.100559  0.151410  0.065409  0.000632  -0.004586
# VIC_AGE_GROUP        1.000000  0.222220 -0.126085 -0.006910  -0.003372
# VIC_RACE             0.222220  1.000000 -0.117610  0.007823   0.001457
# VIC_SEX             -0.126085 -0.117610  1.000000 -0.018837  -0.001611
# weekday             -0.006910  0.007823 -0.018837  1.000000   0.006537
# COMPLETED           -0.003372  0.001457 -0.001611  0.006537   1.000000
# LOCATION_CODE       -0.006494  0.158730 -0.002013 -0.003618  -0.003650
#
#                 LOCATION_CODE
# CMPLNT_NUM          -0.000229
# year                 0.017979
# month               -0.002315
# day                  0.002371
# hour                 0.006734
# ADDR_PCT_CD         -0.336306
# Latitude             0.920158
# Longitude            0.459189
# TARGET               0.031458
# CRIME_CLASS         -0.023550
# BORO_NM              0.270718
# PREM_TYP_DESC       -0.015392
# SUSP_AGE_GROUP       0.014609
# SUSP_RACE            0.019283
# SUSP_SEX             0.005526
# VIC_AGE_GROUP       -0.006494
# VIC_RACE             0.158730
# VIC_SEX             -0.002013
# weekday             -0.003618
# COMPLETED           -0.003650
# LOCATION_CODE        1.000000
#
# [21 rows x 21 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matrice de Corrélation")
plt.show()

# %%
final_data = num_data[['TARGET', 'year', 'month', 'hour', 'weekday', 'ADDR_PCT_CD', 
                       'CRIME_CLASS', 'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX', 'LOCATION_CODE']]

# %%
final_data.to_csv('final_target_data.csv', index=False)

# %%
final_data
# Out:
#          TARGET  year  month  hour  weekday  ADDR_PCT_CD  CRIME_CLASS  \
# 0             0  2013     10    13        0        120.0            0
# 1             1  2012      5    20        2         24.0            0
# 2             0  2014      1    13        4        108.0            1
# 3             0  2014      8    14        0        102.0            0
# 4             1  2012      2     1        0         32.0            0
# ...         ...   ...    ...   ...      ...          ...          ...
# 5259582       0  2018      9    22        1        110.0            1
# 5259583       0  2018      1    14        0         47.0            0
# 5259584       1  2018      8    14        1         78.0            0
# 5259585       1  2018     12     4        6        109.0            0
# 5259586       0  2018      8    22        4         41.0            1
#
#          VIC_AGE_GROUP  VIC_RACE  VIC_SEX  LOCATION_CODE
# 0                    0         0        0           1866
# 1                    1         1        1           9298
# 2                    0         2        0           6804
# 3                    2         0        2           4883
# 4                    3         3        2           9433
# ...                ...       ...      ...            ...
# 5259582              1         1        1           6778
# 5259583              0         3        2          10689
# 5259584              2         3        0           4001
# 5259585              3         2        2           8555
# 5259586              3         4        2           9468
#
# [4612689 rows x 11 columns]
